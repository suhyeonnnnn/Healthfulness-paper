# %%
#필요라이브러리 다운로드 
from matplotlib import font_manager, rc
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import platform 

#한글 폰트 설정
plt.rc('font', family='Malgun Gothic')

#그래프에서 마이너스 표시되게
matplotlib.rcParams['axes.unicode_minus']=False

# %%
#데이터 로드 
df = pd.read_csv("C:\\Users\\sh921\\Dropbox\\2021 SSCI\\3. data and analysis\\data\\master_0820_4 - 복사본.csv")
#데이터 크기, 데이터 상단출력
display(df.shape, df.head())
# Out:
# (7219, 51)
#   company brand  year  quarter  meals  dairy  snacks  beverage  q.trend  \
# 0  CJ제일제당    스팸  2014        2      1      0       0         0       11
# 1  CJ제일제당   맥스봉  2019        4      1      0       0         0       33
# 2  CJ제일제당  행복한콩  2016        1      1      0       0         0       18
# 3  CJ제일제당  행복한콩  2015        2      1      0       0         0       15
# 4  CJ제일제당   백설햄  2018        1      1      0       0         0       26
#
#    y.trend  ...  year16  year17  year18  year19  quarter1  quarter2  quarter3  \
# 0        4  ...       0       0       0       0         0         1         0
# 1        9  ...       0       0       0       1         0         0         0
# 2        6  ...       1       0       0       0         1         0         0
# 3        5  ...       0       0       0       0         0         1         0
# 4        8  ...       0       0       1       0         1         0         0
#
#    quarter4  product_scope  product_max
# ...

# %%
#칼럼 출력 및 결측치 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7219 entries, 0 to 7218
# Data columns (total 51 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   company            7219 non-null   object
#  1   brand              7219 non-null   object
#  2   year               7219 non-null   int64
#  3   quarter            7219 non-null   int64
#  4   meals              7219 non-null   int64
#  5   dairy              7219 non-null   int64
#  6   snacks             7219 non-null   int64
#  7   beverage           7219 non-null   int64
#  8   q.trend            7219 non-null   int64
#  9   y.trend            7219 non-null   int64
#  10  product_count      7219 non-null   int64
#  11  cpi                7219 non-null   float64
#  12  cpi_food           7219 non-null   float64
#  13  tableuse           7219 non-null   float64
#  14  BMI                7219 non-null   float64
#  15  product_type       7219 non-null   int64
# ...

# %%
#데이터 기초통계량 확인
df.describe()
# Out:
#               year      quarter        meals        dairy       snacks  \
# count  7219.000000  7219.000000  7219.000000  7219.000000  7219.000000
# mean   2015.799695     2.513506     0.207369     0.193517     0.331763
# std       2.256801     1.119206     0.405451     0.395082     0.470879
# min    2012.000000     1.000000     0.000000     0.000000     0.000000
# 25%    2014.000000     2.000000     0.000000     0.000000     0.000000
# 50%    2016.000000     3.000000     0.000000     0.000000     0.000000
# 75%    2018.000000     4.000000     0.000000     0.000000     1.000000
# max    2019.000000     4.000000     1.000000     1.000000     1.000000
#
#           beverage      q.trend      y.trend  product_count          cpi  ...  \
# count  7219.000000  7219.000000  7219.000000    7219.000000  7219.000000  ...
# mean      0.267350    18.711733     5.799557       2.845131   100.030946  ...
# std       0.442607     9.090179     2.256697       3.144239     2.932701  ...
# ...

# %%
#데이터 시각화
df.hist(figsize=(20,20))
#plt.tight_layout() #그래프 간격설정
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#year 변수 관련
display(df['year'].value_counts())
plt.plot(df.groupby('year')['brand'].count())
plt.title('연도별 상품수', size=20)
plt.show
# Out:
# 2019    1064
# 2018    1008
# 2017    1003
# 2016     967
# 2015     886
# 2014     825
# 2013     743
# 2012     723
# Name: year, dtype: int64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 해가 지날수록, 상품 업데이트가 많아지는 것으로 확인

# %%
#데이터 로드 
df2 = pd.read_csv("C:\\Users\\sh921\\Dropbox\\2021 SSCI\\3. data and analysis\\data\\beforeLog.csv")
#데이터 크기, 데이터 상단출력
display(df2.shape, df2.head())
# Out:
# (7541, 55)
#   company brand  year  quarter category subcategory  q.trend  y.trend  \
# 0  CJ제일제당    국밥  2015        3   즉석섭취조리    즉석섭취조리식품       16        5
# 1  CJ제일제당    국밥  2015        4   즉석섭취조리    즉석섭취조리식품       17        5
# 2  CJ제일제당    국밥  2016        1   즉석섭취조리    즉석섭취조리식품       18        6
# 3  CJ제일제당    국밥  2016        2   즉석섭취조리    즉석섭취조리식품       19        6
# 4  CJ제일제당    국밥  2016        3   즉석섭취조리    즉석섭취조리식품       20        6
#
#    fissales  fissales.t.1  ...  product_orientation2  process_orientation2  \
# 0    4476.0        2452.0  ...                 0.282                 0.564
# 1    3957.0        4476.0  ...                 0.282                 0.564
# 2    3283.0        3957.0  ...                 0.284                 0.568
# 3    3176.0        3283.0  ...                 0.284                 0.568
# 4    7095.0        3176.0  ...                 0.284                 0.568
#
#    positive_gain2  negative_loss2  general_claim2  licensing_agreement2  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7541 entries, 0 to 7540
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   company               7541 non-null   object
#  1   brand                 7541 non-null   object
#  2   year                  7541 non-null   int64
#  3   quarter               7541 non-null   int64
#  4   category              7541 non-null   object
#  5   subcategory           7541 non-null   object
#  6   q.trend               7541 non-null   int64
#  7   y.trend               7541 non-null   int64
#  8   fissales              7541 non-null   float64
#  9   fissales.t.1          7541 non-null   float64
#  10  healthfulness         7541 non-null   float64
#  11  kcal                  7541 non-null   float64
#  12  size                  7541 non-null   float64
#  13  ta                    7541 non-null   float64
#  14  liab                  7541 non-null   float64
# ...

# %% [markdown]
# 엥 왜 최종 분석데이터랑 n 값이 다르지???? 어디갔지????????

# %%
df2.describe()
# Out:
#               year      quarter      q.trend      y.trend       fissales  \
# count  7541.000000  7541.000000  7541.000000  7541.000000    7541.000000
# mean   2015.807320     2.514388    18.743138     5.807187   10557.669672
# std       2.255704     1.119379     9.084349     2.255605   12907.622025
# min    2012.000000     1.000000     2.000000     2.000000       0.000000
# 25%    2014.000000     2.000000    11.000000     4.000000    2568.000000
# 50%    2016.000000     3.000000    19.000000     6.000000    6770.000000
# 75%    2018.000000     4.000000    27.000000     8.000000   13190.000000
# max    2019.000000     4.000000    33.000000     9.000000  119992.000000
#
#         fissales.t.1  healthfulness         kcal         size            ta  \
# count    7541.000000    7541.000000  7541.000000  7541.000000  7.541000e+03
# mean    10608.786699      -1.925380   105.978759   169.940355  2.130259e+12
# std     12874.431768       1.238836   122.546672   149.057239  2.887367e+12
# ...

# %%
df.describe()
# Out:
#               year      quarter        meals        dairy       snacks  \
# count  7219.000000  7219.000000  7219.000000  7219.000000  7219.000000
# mean   2015.799695     2.513506     0.207369     0.193517     0.331763
# std       2.256801     1.119206     0.405451     0.395082     0.470879
# min    2012.000000     1.000000     0.000000     0.000000     0.000000
# 25%    2014.000000     2.000000     0.000000     0.000000     0.000000
# 50%    2016.000000     3.000000     0.000000     0.000000     0.000000
# 75%    2018.000000     4.000000     0.000000     0.000000     1.000000
# max    2019.000000     4.000000     1.000000     1.000000     1.000000
#
#           beverage      q.trend      y.trend  product_count          cpi  ...  \
# count  7219.000000  7219.000000  7219.000000    7219.000000  7219.000000  ...
# mean      0.267350    18.711733     5.799557       2.845131   100.030946  ...
# std       0.442607     9.090179     2.256697       3.144239     2.932701  ...
# ...

# %%
#데이터 시각화
df2.hist(figsize=(20,20))
#plt.tight_layout() #그래프 간격설정
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#sales boxplot
plt.figure(figsize=(15,6)) #그래프 크기조정
plt.subplot(1,2,1) 
g = sns.boxplot(x='q.trend', y='fissales', data=df2, showfliers=False)
g.set_title('분기별 Sales 상자그림', size=20)
g.set_xticklabels(g.get_xticklabels(), rotation=90)

plt.subplot(1,2,2)
plt.plot(df2.groupby('q.trend')['fissales'].median())
plt.title('분기별 중앙값', size=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#sales boxplot
plt.figure(figsize=(15,6)) #그래프 크기조정
plt.subplot(1,2,1) 
g = sns.boxplot(x='q.trend', y='sales', data=df, showfliers=False)
g.set_title('분기별 Sales 상자그림', size=20)
g.set_xticklabels(g.get_xticklabels(), rotation=90)

plt.subplot(1,2,2)
plt.plot(df.groupby('q.trend')['sales'].median())
plt.title('분기별 중앙값', size=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df2['fissales'].hist()
# Out:
# <AxesSubplot:>

# %%
display(df2['fissales'].mean(), df2['fissales'].var())
# Out:
# 10557.669672457234
# 166606706.33350804

# %%
display(df['sales'].mean(), df['sales'].var())
# Out:
# 8.439362017173874
# 3.1928150598797393

# %%
df2['healthfulness3'].hist()
# Out:
# <AxesSubplot:>

# %%
display(df2['healthfulness3'].mean(), df2['healthfulness3'].var())
# Out:
# -1.9262104342742472
# 1.5278823793441993

# %%
#피처 스케일링 다시할 변수 입력
beforeScaled = df2[['']]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df2)
fissales_scaled = scaler.transform(df2)

fissales_scaled_df = pd.DataFrame(data=fissales_scaled, columns=df2.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-ca9c7553dedd> in <module>
#       2 from sklearn.preprocessing import StandardScaler
#       3 scaler = StandardScaler()
# ----> 4 scaler.fit(df2)
#       5 fissales_scaled = scaler.transform(df2)
#       6
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
# ...

# %%
df2['healthfulness3'].hist()
# Out:
# <AxesSubplot:>

# %%
beforeLog = pd.read_csv("C:\\Users\\sh921\\Dropbox\\2021 SSCI\\3. data and analysis\\data\\beforeLog2.csv")
beforeLog.head()
# Out:
#   company brand  q.trend  y.trend  fissales  fissales.t.1  health4
# 0  CJ제일제당    국밥       16        5    4476.0        2452.0   -84.60
# 1  CJ제일제당    국밥       17        5    3957.0        4476.0   -84.60
# 2  CJ제일제당    국밥       18        6    3283.0        3957.0   -85.20
# 3  CJ제일제당    국밥       19        6    3176.0        3283.0   -85.20
# 4  CJ제일제당    국밥       20        6    7095.0        3176.0  -107.92

# %%
beforeScaler = beforeLog[['fissales','fissales.t.1','health4']]

# %%
beforeScaler.mean()
# Out:
# fissales        10557.669672
# fissales.t.1    10608.786699
# health4           -83.534602
# dtype: float64

# %%
beforeScaler.var()
# Out:
# fissales        1.666067e+08
# fissales.t.1    1.657510e+08
# health4         1.318316e+03
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(beforeScaler)
scaled = scaler.transform(beforeScaler)

#transform 시 데이터 세트가 ndarray로 반환되므로, 데이터 프레임으로 변환
scaled_df = pd.DataFrame(scaled, columns=('sales_scaled','salest.1_scaled','health_scaled'))
scaled_df.head()
# Out:
#    sales_scaled  salest.1_scaled  health_scaled
# 0     -0.471200        -0.633607      -0.029345
# 1     -0.511412        -0.476386      -0.029345
# 2     -0.563632        -0.516701      -0.045871
# 3     -0.571922        -0.569056      -0.045871
# 4     -0.268283        -0.577368      -0.671659

# %%
scaled_df.mean()
# Out:
# sales_scaled      -1.329588e-16
# salest.1_scaled   -2.545224e-16
# health_scaled     -1.277029e-15
# dtype: float64

# %%
scaled_df.var()
# Out:
# sales_scaled       1.000133
# salest.1_scaled    1.000133
# health_scaled      1.000133
# dtype: float64

# %%
beforeLog= pd.concat([beforeLog, scaled_df],axis=1)
beforeLog.isna().sum()
# Out:
# company            0
# brand              0
# q.trend            0
# y.trend            0
# fissales           0
# fissales.t.1       0
# health4            0
# sales_scaled       0
# salest.1_scaled    0
# health_scaled      0
# sales_scaled       0
# salest.1_scaled    0
# health_scaled      0
# dtype: int64

# %%
#데이터 시각화
beforeLog.hist(figsize=(20,20))
#plt.tight_layout() #그래프 간격설정
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.preprocessing import Normalizer
scaler = Normalizer()
scaler.fit(beforeScaler)
scaled = scaler.transform(beforeScaler)

#transform 시 데이터 세트가 ndarray로 반환되므로, 데이터 프레임으로 변환
scaled_df = pd.DataFrame(scaled, columns=('sales_scaled','salest.1_scaled','health_scaled'))
scaled_df.head()
# Out:
#    sales_scaled  salest.1_scaled  health_scaled
# 0      0.876905         0.480378      -0.016574
# 1      0.662269         0.749132      -0.014159
# 2      0.638431         0.769501      -0.016568
# 3      0.695177         0.718597      -0.018649
# 4      0.912638         0.408533      -0.013882

# %%
#데이터 시각화
scaled_df.hist(figsize=(20,20))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
